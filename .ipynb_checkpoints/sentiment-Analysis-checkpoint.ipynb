# %%
import re
import emot
import nltk
import numpy as np
import pandas as pd
from nltk import pos_tag
from textblob import TextBlob
from nltk.corpus import gazetteers
from nltk.classify import MaxentClassifier
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('gazetteers')
nltk.download('conll2002')
nltk.download('punkt')
nltk.download('brown')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package gazetteers to
# [nltk_data]     /home/hosseinhimself/nltk_data...
# [nltk_data]   Package gazetteers is already up-to-date!
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     /home/hosseinhimself/nltk_data...
# [nltk_data]   Package conll2002 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/hosseinhimself/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     /home/hosseinhimself/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/hosseinhimself/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def replace_emoji(text):
    emot_obj = emot.core.emot()
    emotes = emot_obj.emoji(text)
    for i in range(len(emotes['value'])):
        text = text.replace(emotes['value'][i], emotes['mean'][i])
    return text


def normalize(text):
    link_pattern = r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)"
    text = re.sub(link_pattern, '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    text = replace_emoji(text)
    text = text.replace('\n',' ')
    return text

# %%
data = pd.read_csv("twitter-scraper/scraped_tweets_missingbaby.csv")

# %%
data.head()
# Out:
#    Unnamed: 0       username  \
# 0           0       JISTLAB_
# 1           1  Abdul42920472
# 2           2      VaclavusU
# 3           3      VaclavusU
# 4           4   colinwitcher
#
#                                          description  \
# 0                               ⛅️ 🇨🇦🇲🇦 IG ~ JISTLAB
# 1                                                NaN
# 2  US,UK,World Politics,ShowBiz,Sport Celebrities...
# 3  US,UK,World Politics,ShowBiz,Sport Celebrities...
# 4  Barrister specialising in General Crime and Bu...
#
#                         location  following  followers  totaltweets  \
# 0               Montréal, Québec        160        135        48087
# 1                            NaN         68          2          310
# 2  SE 256th street Kent, WA, USA         54         17        24121
# 3  SE 256th street Kent, WA, USA         54         17        24121
# 4                London, England       1649       2524         2234
#
#    retweetcount                                               link  \
# 0            22  https://twitter.com/i/web/status/1632739441830...
# 1            26  https://twitter.com/i/web/status/1632735132611...
# 2             0  https://twitter.com/i/web/status/1632731896047...
# 3             0  https://twitter.com/i/web/status/1632731355392...
# 4             1  https://twitter.com/i/web/status/1632721208163...
#
#                                                 text hashtags
# 0  Runaway British Mum, Constance Marten, Charged...       []
# 1  Detectives continue to quiz Constance Marten a...       []
# 2  Constance Marten and Mark Gordon blow each oth...       []
# 3  Constance Marten and Mark Gordon named baby be...       []
# 4  Lewis Power KC and @colinwitcher instructed on...       []

# %%
analyzer = SentimentIntensityAnalyzer()

# Define a dictionary to map the sentiment scores to emotions
emotion_dict = {'angry':0,
               'upset': 0,
               'nutural':0,
               'curious':0,
               'happy':0}

all_scores = []

# Loop through each tweet and determine the emotion
for tweet in tweets:
    # Get the sentiment score for the tweet
    sentiment_score = analyzer.polarity_scores(normalize(tweet))
    all_scores.append(sentiment_score)
    # Determine the emotion based on the sentiment score
    
    if sentiment_score['neg'] > sentiment_score['pos']:
        if sentiment_score['neg'] > sentiment_score['neu']:
            emotion_dict['angry'] += 1
        else:
            emotion_dict['upset'] += 1
            
            
    elif sentiment_score['pos'] > sentiment_score['neg']:
        if sentiment_score['pos'] > sentiment_score['neu']:
            emotion_dict['happy'] += 1
        else:
            emotion_dict['curious'] += 1
            
            
    else:
        if sentiment_score['neu'] > 0.5:
            emotion_dict['nutural'] += 1

# %%
# Print the count of each emotion
for emotion, count in emotion_dict.items():
    print(f"{emotion}: {count}")
# Out:
# angry: 131
# upset: 7186
# nutural: 1182
# curious: 1286
# happy: 16

# %%
compound_scores = []
for tweet_scores in all_scores:
    compound_scores.append(tweet_scores['compound'])
    
scores = np.array(compound_scores)

x = np.array(['Positive', 'Nutural', 'Negative'])
y = np.array([np.sum(scores > 0), np.sum(scores == 0), np.sum(scores < 0)])

# Create bar chart
plt.bar(x, y)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar chart example')

# Show chart
plt.show()

# %%
compound_scores = []
for tweet_scores in all_scores:
    compound_scores.append(tweet_scores['compound'])
    
scores = np.array(compound_scores)

x = np.array([emotion for emotion in emotion_dict.keys()])
y = np.array([emotion[1] for emotion in emotion_dict.items()])

# Create bar chart
plt.bar(x, y)

# Write the number of each bar above it
for i, v in enumerate(y):
    plt.text(i, v + 0.2, str(v), ha='center')

# Add labels and title
plt.xlabel('Emotions categories', fontweight="bold", color="red")
plt.ylabel('Values', fontweight="bold", color="red")
plt.title('Bar Chart Based on Emotions', fontweight="bold", color="red")

# Show chart
plt.show()

# %%
import ast

hashtags = []
for tags_list in data['hashtags']:
    if tags_list != '[]':
        tag_list = ast.literal_eval(tags_list)
        for hashtag in tag_list:
            hashtags.append(hashtag)

hashtags = np.array(hashtags)

# %%
unique, counts = np.unique(hashtags, return_counts=True)
hashtag_dict = {'hashtags':unique, 'counts':counts}

# %%
hashtags_table = pd.DataFrame(hashtag_dict).sort_values(by='counts', ascending=False)

# %%
hashtags_table.head(5)
# Out:
#             hashtags  counts
# 203  constancemarten     158
# 26          Brighton     116
# 40   ConstanceMarten     103
# 22          Breaking      70
# 93        MarkGordon      66

# %%
data.sort_values(by='followers', ascending=False)[['username', 'followers']].drop_duplicates(subset='username').head(20)
# Out:
#              username  followers
# 4018           cnnbrk   64195142
# 4068              CNN   61267702
# 2797      BBCBreaking   51682355
# 947          BBCWorld   39609526
# 5450          BBCNews   15060185
# 4066             cnni   14473199
# 7978         HuffPost   11204819
# 9730         guardian   10895482
# 8140          CBSNews    8918937
# 9455          SkyNews    8371899
# 5090     SkyNewsBreak    4992359
# 104   SaharaReporters    4954862
# 9717     guardiannews    3863436
# 9702      Independent    3628449
# 9363        Telegraph    3378165
# 6532       MailOnline    2820638
# 9373          itvnews    2611789
# 4827     Channel4News    2473570
# 8246           TheSun    2065794
# 8459             VICE    2015297

# %%
locations = [location for location in data.drop_duplicates(subset='username')['location']]

# %%
for location in locations:
    if type(location) == str:
        locat = replace_emoji(location)
        locat.replace(':','')
        locat.replace('_',',')
        
        print(locat.split(', '))
# Out:
# ['Montréal', 'Québec']
# ['SE 256th street Kent', 'WA', 'USA']
# ['London', 'England']
# ['Brighton', 'England']
# ['Worthing']
# ['London', 'England']
# ['Bangalore']
# ['London', 'EC4Y 7BL']
# ['Buckingham', 'England']
# ['United Kingdom']
# ['Kent', 'WA', 'USA 98032']
# ['United States']
# ['Italia']
# ['Nigeria']
# ['USA']
# ['Los Angeles', 'CA']
# ['Northumbria', 'Great Britain']
# ['Sharingan']
# ['Ireland']
# ['In my flat']
# ['Knoxville Tennessee ']
# ['Kent', 'WA', 'USA']
# [' Englandstan']
# ['Massachusetts', 'USA']
# ['Biafra']
# ['InMyCave']
# ['Buckinghamshire', 'UK.']
# ['North America']
# ['UK']
# ['Nottingham', 'England']
# ["God's Country"]
# ['Terra']
# ['The real world :globe_showing_Americas:']
# ['England', 'United Kingdom']
# ['West is the best ']
# ['United Kingdom']
# ['London', 'UK']
# ['Beverly Hills', 'CA']
# ['United States']
# ['Everywhere']
# ['Strange town uk']
# ['ipswich']
# ['Nigeria']
# ['Sussex by the Sea']
# ['lagos']
# ["Buhari's anus"]
# [':globe_showing_Europe-Africa:']
# ['Lagos', 'Nigeria']
# ['Arkansas', 'USA']
# ['Mahlanyeng', 'South Africa']
# ['Lagos', 'Nigeria']
# ['New York']
# ['Trenton', 'New Jersey USA']
# ['London', 'England']
# ['Abuja', 'Nigeria']
# ['England']
# ['United Kingdom']
# ['Portsmouth', 'England']
# ['world']
# ['London']
# ['England', 'United Kingdom']
# ['Goole', 'England']
# ['Nigeria']
# ['Manchester and London']
# ['Britain first ']
# ['United States']
# [':Nigeria: :United_Kingdom:']
# ['michelle or nana']
# ['Working for Better Nigeria']
# ['Inside Life ']
# ['Middle of earth']
# ['Nigeria']
# ['Cambridge!']
# ['Salt Lake City', 'Utah and Miami']
# ['Gloucestershire']
# ['Southwest Missouri']
# ['United Kingdom']
# ['East Yorkshire - England']
# ['Brighton', 'England']
# ['Worldwide']
# ['Never']
# ['Brighton', 'England']
# ['England', 'United Kingdom']
# ['Dover', 'England']
# ['Glasgow', 'UK']
# ['Newport', 'South Wales']
# ['Dublin', 'Ireland']
# ['United Kingdom ']
# ['Doncaster (South Yorkshire)']
# ['South West', 'England']
# ['England', 'United Kingdom']
# ['Llanelli', 'Wales']
# ['Brighton and Hove', 'UK']
# ['England', 'United Kingdom']
# ['Elgin', 'Scotland']
# ['London', 'England']
# ['on Earth! ']
# ['Bengaluru South', 'India']
# ['Uk  ']
# ['VITORIA-ES/ BRASIL . ']
# ['United Kingdom']
# ['England', 'Brighton. :United_Kingdom:']
# ['Birmingham']
# ['Kent', 'UK']
# ['Planet Arcturus']
# ['London', 'UK']
# ['Essen  - Germany']
# ['United States']
# ['Weymouth', 'England']
# ['#OH11']
# ['London', 'England']
# ['London']
# ['Lost in Somerset ']
# ['Atlanta', 'GA']
# ['Manchester', 'England']
# ['United Kingdom']
# ['Portugal']
# ['Stirling: NATION OF CALEDONIA']
# ['England', 'United Kingdom']
# ['London', 'England']
# ['Essex']
# ['None of yours']
# ['London', 'England']
# ['England']
# ['Scotland']
# ['Gosport', 'Hants']
# ['Dublin City', 'Ireland']
# ['Raleigh', 'North Carolina']
# ['South West', 'England']
# ['Plymouth']
# ['United Kingdom']
# ['England', 'United Kingdom']
# ['Manchester', 'England']
# ['Here ']
# ['West London baby']
# ['Australia :Australia: ']
# ['Gibraltar']
# ['United Kingdom']
# ['Allenstown AU / Cardiff']
# ['Kirkintilloch', 'Scotland']
# ['Gr Manchester']
# ['London', 'England']
# ['London/Essex border']
# ['United Kingdom & proud of it !']
# ['Dublin']
# ['London', 'England']
# ['Toronto and Palm Beach Gardens']
# ['London', 'UK']
# ['Swansea', 'Wales']
# ['Cornwall', 'England']
# ['UK']
# ['South West', 'England']
# ['West Lancs/Bath']
# ['London']
# ['United Kingdom']
# ['South East', 'England']
# ['Scotland ']
# ['United Kingdom']
# ['London', 'England']
# ['Ukunda', 'Kenya']
# ['somewhere ']
# ['London']
# ['England', 'United Kingdom']
# ['California']
# ['United Kingdom']
# ['Ireland']
# ['Kenya']
# ['Brooklyn-bred. London-living.']
# ['Horndean', 'England']
# ['Credenhill', 'England']
# ['los angeles']
# ['United Kingdom']
# ['Dallas', 'TX']
# ['Kumasi', 'Ghana']
# ['united state and global']
# ['East Midlands', 'England']
# ['Ireland']
# ['In a village']
# ['East Sussex']
# ['Planet Earth ']
# ['Manhattan', 'NY']
# ['Arkansas']
# ['South Wales']
# ['Cornwall']
# ['Where I need to be!']
# ['Brighton/South Stand']
# ['US']
# ['Scotland']
# ['10th circle of paradise']
# ['Bridstow', 'England']
# [' By the River Nidd! Yorkshire.']
# ['The Netherlands']
# ['bussin splits on ya mums grave']
# ['Texas', 'USA']
# ['Horsham', 'England']
# ['México']
# ['UK']
# ['southampton uk']
# ['On a planet far far away']
# ['london']
# ['Earth']
# ['Lehigh Valley']
# ['Liverpool UK ']
# ['vancouver bc canada']
# ['Edinburgh', 'Scotland']
# ['London', 'England']
# ['Lagos', 'Nigeria']
# ['London', 'UK']
# ['Madrid Spain ']
# ['London', 'England']
# ['Reading & Brighton ']
# ['London', 'England']
# ['London', 'England']
# ['Green Gables']
# ['Metropolitan Police UK']
# ['Cornwall']
# ['London', 'England']
# ['Clare', 'Ireland']
# ['England', 'United Kingdom']
# ['Black libreratio is salvation ']
# ['England', 'United Kingdom']
# ['England', 'United Kingdom']
# ['NYC']
# ['Seven Kings', 'Ilford', 'Essex']
# ['Bolton']
# ['Manchester', 'England']
# ['On the interweb']
# ['London']
# ['Leeds']
# ['New York City']
# ['London', 'England']
# ['Here', 'there and everywhere']
# ['United Kingdom']
# ['Edwarebury snt', 'England']
# ['Dorset']
# ['Manchester', 'UK']
# ['Dublin City', 'Ireland']
# ['York', 'England']
# ['Point Clear', 'England']
# ['London(ish)']
# ['Essex']
# ['London']
# ['Purgatory']
# ['Manchester', 'England']
# ['Rijssen']
# ['London', 'England']
# ['UK', 'Europe. ish.']
# ['United States']
# ['Spain & Florida']
# ['Teesside', 'North East']
# ['Derby', 'Dubai']
# ['London', 'England']
# ['Crawley', 'South East']
# ['Sheffield']
# ['thechiefcoin.bitcoin']
# ['England']
# ['London']
# ['Essex']
# ['England', 'United Kingdom']
# ['Bedford']
# ['London', 'England']
# [':Canada::United_States::rainbow_flag:']
# ['Brighton', 'England']
# ['London']
# ['Johannesburg', 'South Africa']
# ["Queenie's Castle,Yate", 'S Glos']
# ['Brazil']
# ['Inveterate itinerate: settled']
# ['Earth along with everyone else']
# ['Swansea', 'Wales']
# ['Tim Bucked two ']
# ['United States']
# ['Carlisle', 'England']
# [' Heaven']
# ['European Union']
# ['San Diego']
# ['West Berkshire']
# ['Bengaluru', 'India']
# ['North West', '(UK).']
# ['Eastlothian']
# ['London']
# ['London', 'England']
# ['South East', 'England']
# ['uk']
# ['Salford', 'England']
# ['London']
# ['Akka', 'Israel']
# ['United Kingdom']
# ['London']
# ['Your head']
# ['Yorkshire.']
# ['U.K.']
# ['London', 'England']
# ['Liverpool', 'UK']
# ['Stoke on Trent']
# ['London ']
# ['Ireland']
# ['Happiness is not an ideal of reason', 'but of imagination.']
# ['the cotswolds']
# ['Lingfield', 'South East']
# ['SoCal']
# ['(ૢෆ癶◡癶ෆ) ૢ']
# ['Carlton', 'England']
# ['Leeds', 'England']
# ['Glanworth', 'Cork', 'Ireland ']
# ['UK']
# ['UK']
# ['Diksmuide', 'België']
# ['Northerner near the humber ']
# ['Sussex']
# ['The United States']
# ['Nepal']
# ['London/Londres', 'Angleterre']
# ['London :blue_heart: England', 'UK']
# [' USA  ']
# ['Snodland', 'South East']
# ['East Leeds Leeds Leeds']
# ['Where my mind calls home.']
# ['الرياض', 'المملكة العربية السعود']
# ['England', 'United Kingdom']
# ['England']
# ['Bucks and Ireland ']
# ['London', 'England,Casablanca,Etc']
# ['London', 'England']
# ['After a good night’s sleep ']
# [':snowman_without_snow:️:snowflake:️Costa Del Custardy :snowflake:️:snowman_without_snow:️']
# ['London']
# ['London']
# ['termeloh ']
# ['London']
# ['New Jersey', 'mostly']
# ['ITV News Meridian']
# ['Long Beach', 'CA']
# ['Eastbourne']
# ['United Kingdom']
# ['Livingston', 'Scotland']
# ['Who Knows?  :)']
# ['Planet Earth']
# ['Stornoway', 'Scotland']
# ['Las Americas']
# ['Canada']
# ['Scotland']
# ['New York', 'NY']
# ['Lapsed kingdom']
# ['Johannesburg', 'South Africa']
# ['Ireland']
# ['Hertfordshire UK ']
# ['Scotland']
# ['USA']
# ['Worcestershire England ']
# ['Manchester', 'England']
# ['England']
# ['England', 'UK']
# ['United Kingdom']
# ['UK']
# ['London']
# ['England', 'United Kingdom']
# ['Stoke-on-Trent', 'England']
# ['Brighton', 'UK']
# ['Liverpool', 'England']
# ['London', 'England']
# ['UK']
# ['Sussex']
# ['Temple Mount', 'Jerusalem']
# ['UK']
# ['North West', 'England']
# ['Kaduna ']
# ['East', 'England']
# ['Garden of England']
# ['Studland', 'England']
# ['Boroughbridge', 'England']
# ['Uk']
# ['The Lone Star State']
# ['UK & Asia']
# ['Unhoused']
# ['Burnley', 'Lancashire']
# ['The Ochils']
# ['England']
# ['Riga']
# ['London']
# ['United Kingdom']
# ['East Dennis', 'MA ']
# ['North West', 'England']
# ['Brighton & Hove', 'UK']
# ['London', 'England']
# ['South West', 'England']
# ['London']
# ['Ocean City UK']
# [':Scotland:']
# ['Doncaster yorkshire zuk']
# ['London', 'England']
# ['London', 'England']
# ['Sourton', 'Okehampton', 'Devon.']
# ['Newcastle upon Tyne', 'UK']
# ['Winchester', 'Hampshire.']
# ['United Kingdom']
# ['Salisbury Wiltshire ', 'England']
# ['London', 'England']
# ['United Kingdom']
# ['Birmingham', 'England']
# ['Nottinghamshire']
# ['Oldham', 'England']
# ['London']
# ['Buenos Airrs']
# [':red_circle::red_circle:']
# ['United Kingdom']
# ['Antrim', 'Northern Ireland']
# ['Brighton and Hove']
# ['London', 'England']
# ['Ivebeeneverywhereman']
# ['Chasm of the Undead']
# ['England', 'United Kingdom']
# ['Albert Square', 'Manchester UK']
# ['Bristol', 'UK']
# ['Ghana']
# ['Mumbai', 'India']
# ['London Town']
# ['Hill Valley/Hill Dale']
# ['Saskatchewan', 'Canada']
# [' South Africa']
# ['Bedfordshire ']
# ['Havering']
# ['lagos nigeria']
# ['London', 'UK']
# ['Sydney', 'New South Wales']
# ['East Sussex & Train Traveller']
# ['UK & USA']
# ['Witney', 'England']
# ['Iraq']
# ['England', 'United Kingdom']
# ['LONDON']
# ['Milton Keynes', 'Buckinghamshire']
# ['United Kingdom']
# ['London', 'UK']
# ['Nigeria']
# ['Harare', 'Zimbabwe']
# ['Kampala', 'Uganda']
# ['Kent']
# ['Brighton ']
# ['S.F.via N.Y.']
# ['Lincolnshire', 'UK']
# ['Accra', 'Ghana']
# ['Holding the #ThinBlueLine']
# ['Washington', 'DC']
# ['London', 'England']
# ['Leeds']
# ['Worthing', 'England']
# ['Surrey', 'Sussex or Cornwall']
# ['Manchester', 'England']
# ['England', 'United Kingdom']
# ['Aberdeen', 'Scotland']
# ['Brighton & Hove', 'UK']
# ['Brighton', 'Sussex', 'UK']
# ['England', 'United Kingdom']
# ['Preston', 'England']
# ['Scotland', 'United Kingdom']
# ['Tunbridge Wells']
# ['oxford']
# ['Dorset']
# ['Edmonton', 'Alberta']
# ['South Coast']
# ['Bournemouth & Poole']
# ['Fareham', 'England']
# ['Canterbury', 'England']
# ['Shropshire']
# ['New York', 'NY']
# ['New York']
# ['Matthew 24:4-31\xa0Kjv']
# ['Henley-on-Thames', 'England']
# ['Up in ur timeline']
# ['Used to be EU']
# ['London', 'UK']
# ['London']
# ['London', 'UK']
# ['United States']
# ['Devon']
# ['London', 'UK']
# ['Wales']
# ['United Kingdom']
# ['Dudley & South London']
# ['Manchester', 'England']
# ['Wigan', 'England']
# ['North East', 'England']
# ['London']
# ['UK']
# ['Santa Cruz de Tenerife', 'Spain']
# ['Cloud 9']
# ['Rugby Warwickshire']
# ['Northumberland england']
# ['Great Barr with Yew Tree #WBE']
# ['London - Leeds - The World ']
# ['South West', 'England']
# ['Solihull']
# ['Acapulco de Juárez', 'Guerrero']
# ['West Midlands']
# ['Birmingham', 'UK']
# ['Birmingham']
# ['The Cotswolds']
# ['Broadcasting House', 'London']
# ['HERE']
# ['UK ']
# ['third rock from the sun ']
# ['Manchester', 'England']
# ['Portsmouth', 'England']
# ['London']
# ['cambridgeshire ']
# ['England', 'United Kingdom']
# ['Dayton', 'OH']
# ['Ireland']
# ['Greenwich', 'London']
# ['Extreme Far Left :bouquet::red_heart:️:cat::cat:\u200d⬛:poodle:']
# ['Cardiff / Caerdydd ']
# ['Blackburn']
# ['Northern Ireland', 'UK :United_Kingdom: ']
# ['Japan ']
# ['United Kingdom']
# ['London', 'England']
# ['England', 'United Kingdom']
# ['UK']
# ['London via Glasgow']
# ['South East', 'England ']
# ['UK']
# ['Falkirk', 'Scotland']
# ['East London to Raqqa :palm_tree:']
# ['Dublin', 'Ireland']
# ['Swat', 'Khyber Pakhtunkhwa ']
# ['Liverpool']
# ['La Paz', 'BCS']
# ['West Midlands', 'England']
# ['Scotland', 'United Kingdom']
# ['UK']
# ['London', 'Mostly.']
# ['NOTTINGHAMSHIRE UK']
# ['england. From Belfast. ']
# ['United Kingdom']
# ['International']
# ['Hemsworth', 'England']
# ['Liverpool UK ']
# ['UK']
# ['UK']
# ['Wales']
# ['Gosport UK']
# ['London', 'England']
# ['Southampton', 'UK.']
# ['London']
# ['Romford', 'London']
# ['Liverpool', 'UK']
# ['United Kingdom']
# ['Paris', 'France']
# ['pwd']
# ['United Kingdom']
# ['Tiruchirapalli', 'India']
# ['Bath']
# ['United Kingdom']
# ['London']
# ['A Pale Blue Dot']
# ['Bathgate Scotland']
# ['Yorkshire UK']
# ['London']
# ['Weymouth', 'Dorset']
# ['London']
# ['London', 'United Kingdom']
# ['ROMANIA ']
# ['UK']
# ['cambridge']
# ['United Kingdom']
# ['United Kingdom']
# ['UK']
# ['West Sussex']
# ['Cornwall and hampshire']
# ['Greater Toronto Area']
# ['England', 'United Kingdom']
# ['East Sussex']
# ['UK']
# ['United States of America']
# ['Ayr :Scotland: :United_Kingdom:']
# ['Various']
# ['London', 'United Kingdom ']
# ['United States']
# [' ']
# ['United Kingdom']
# ['East Kilbride', 'United Kingdom']
# ['London', 'England']
# ['Wolverhampton']
# ['United Kingdom']
# ['Methil', 'Scotland']
# ['Slough']
# ['UK']
# ['UK and Ireland']
# ['England', 'United Kingdom']
# ['Devon', 'UK']
# ['Poole', 'England']
# ['Proud of :trophy: Los Angeles ']
# ['Tamworth']
# ['London', 'England']
# ['Sydney']
# ['South Benfleet', 'Essex', 'UK']
# ['Manchester U.K']
# ['Manchester', 'England']
# ['United Kingdom']
# ['In My Own World Of #MSquirks ']
# ['London', 'UK']
# ['London', 'UK']
# ['south yorkshire']
# ['London ']
# ['London ']
# ['Indianapolis', 'IN']
# ['NWUK']
# ['United Kingdom']
# ['Bristol', 'England']
# ['Manc and Proud ']
# ['Bury', 'England']
# ['Bangladesh']
# ['Chelmsford', 'Essex']
# ['San Miguel De Salinas']
# ['Leicester']
# ['United Kingdom']
# ['LEICS', 'England', 'UK/GB :United_Kingdom:']
# ['Daybrook ', 'Nottingham.']
# ['UK and Worldwide. ']
# ['Newcastle Upon Tyne']
# ['Glastonbury', 'England']
# ['Dublin']
# ['UK-THAILAND-SOUT KOREA']
# ['England', 'United Kingdom']
# ['Mamelodi', 'Pitori']
# ['Manchester', 'England']
# ['Cambridge', 'England']
# ['Scotland']
# ['England', 'United Kingdom']
# ['London', 'England']
# ['London', 'England']
# ['Here', 'there and everywhere! ']
# ['England']
# ['New Delhi', 'India']
# ['United States']
# ['Bengaluru', 'India']
# ['UK']
# ['email: amtum2018@gmail.com']
# ['Newark', 'NJ']
# ['Dundee', 'Scotland']
# ['United Kingdom']
# ['Scotland', 'United Kingdom']
# ['london']
# ['South East', 'England.. ']
# ['UK']
# [' England.:United_Kingdom:']
# ['United Kingdom']
# ['United Kingdom']
# ['Hong Kong']
# ['New York', 'NY']
# ['15 Queen St', 'Colchester', 'Essex']
# ['Hong Kong / London']
# ['India']
# ['England', 'United Kingdom']
# ['Worldwide']
# ['Ghana']
# ['England', 'United Kingdom']
# ['Madrid', 'Spain']
# ['Chicago', 'IL']
# ['East Coast', 'USA']
# ['Essex']
# ['London', 'UK']
# ['London', 'England']
# ['Brighton', 'England']
# ['London']
# ['Somerset', 'UK']
# ['Vladivostok', 'Russia']
# ['Earth']
# ['Orbiting London']
# ['London', 'England']
# ['Falkirk', 'Scotland']
# ['www.westwickhamfitness.com']
# ['Bournemouth', 'England']
# ['Northampton', 'England']
# ['Read The Real Silence Mag :down_arrow:️']
# ['UK']
# ['England', 'United Kingdom']
# ['Walthamstow', 'London']
# ['UK']
# ['Dorset', 'UK']
# ['London/Essex ']
# ['Islington', 'London']
# ['Isle of Man']
# ['Cambridgeshire uk ']
# ['England']
# ['Greater Manchester / Cheshire']
# ['TalkTV']
# ['England']
# ['London', 'England']
# ['sometimes here sometimes there']
# ['Crazyville', 'Bristol']
# ['New Jersey']
# ['Leeds Belfast- Irish Diaspora']
# ['Wolverhampton', 'England']
# ['London', 'England']
# ['Ballymoney', 'Northern Ireland']
# ['Ireland']
# ['MediaCityUK', 'Salford']
# ['UK']
# ['North East of England']
# ['North East of England']
# ['Shropshire', 'UK']
# ['Gosport', 'Hampshire', 'UK']
# ['London', 'England']
# ['North West', 'England']
# ['Ireland']
# ['North West England']
# ['ประเทศไทย']
# ['ประเทศไทย']
# ['London', 'England']
# ['London']
# ['Hampshire :United_Kingdom:Ex McLarenF1. ']
# ['Yorkshire and The Humber']
# ['Kent']
# ['London', 'England']
# ['Reading', 'England']
# ['Amsterdam', 'The Netherlands']
# ['Penarth', 'Wales']
# ['New York', 'USA']
# ['South West Scotland']
# ['London', 'England']
# ['the world']
# ['UK']
# [':world_map: Newsworthy Tweet Relay']
# ['Malaysia']
# ['Saskatchewan', 'Canada']
# ['Brisbane ']
# ['Bristol', 'England']
# ['Cambodia']
# ['England', 'United Kingdom']
# ['leeds']
# ['Dunfermline', 'Scotland']
# ['West Haven Cresent']
# ['London', 'England']
# ['United States']
# ['United States']
# ['Walton-on-Thames']
# ['Somewhere out there ']
# ['cyberspace']
# ['Michigan', 'USA']
# ['London', 'England']
# ['USA ']
# ['Cardiff', 'UK']
# ['London', 'England']
# ['London ']
# ['Ireland | Scotland | Inuit | Skandinavien']
# ['London', 'England']
# ['#freeassange']
# ['Las Vegas', 'NV']
# ['London', 'England']
# ['USA']
# ['Bangalore', 'India']
# ['uk']
# ['London']
# ['Bolton', 'England']
# ['Nagpur', 'India']
# ['United Kingdomistan']
# ['United Kingdom']
# ['Colorado', 'United States ']
# ['London', 'England']
# ['northern Ireland ']
# ['Windsor', 'United Kingdom. ']
# ['hull']
# ['Fylde Coast. Lancs England']
# ['gravesend', 'kent', 'england']
# ['Nairobi', 'Kenya']
# ['Australia']
# ['England', 'United Kingdom']
# ['Scotland', 'United Kingdom']
# ['UK']
# ['Chicago']
# ['Wales']
# ['paisley', 'glasgow']
# ['Mancunian living in London!!!']
# ['Tarbolton', 'Scotland']
# ['Worldwide']
# ['Texas ']
# ['London']
# ['Scotland', 'United Kingdom']
# ['Sheffield', 'England']
# ['South East England']
# ['Sheffield', 'England']
# ['South Woodham Ferrers']
# ['USA']
# ['APOBANGPO ♡']
# ['On my blankie', 'furever.']
# ['St Albans ']
# ['Cali Yuga']
# ['England', 'United Kingdom']
# ['Japan']
# ['Europe']
# ['Somewhere...out there.....']
# ['Living in hope in SWUK']
# ['UK']
# ['England', 'United Kingdom']
# ['South East', 'England']
# ['Glasgow ']
# ['barking essex']
# ['USA']
# ['England', 'United Kingdom']
# ['OR', 'United States']
# ['London']
# ['Indonesia']
# ['Planet Earth']
# ['Kumasi', 'Ghana']
# ['Scotland', 'United Kingdom']
# ['Villa Martin', 'Spain']
# ['UK South and London']
# ['Dystopian Nightmare']
# ['Sussex', 'UK']
# ['Hornsea', 'England']
# ['United Kingdom']
# ['Brasil']
# ['East', 'England']
# ['she/her newcastle']
# ['Wales. Top left']
# ['Municipio de Medellín']
# ['Belfast', 'Northern Ireland']
# ['United Kingdom']
# ['Rojales', 'España']
# ['United Kingdom']
# ['Mars']
# ['South East', 'England']
# ['England', 'United Kingdom']
# ['Ireland']
# ['Sunny Cheshire :-/ ']
# ['Glasgow', 'Scotland']
# ['Mile HI State']
# ['Florida', 'USA']
# ['Hull', 'England']
# ['UTV Region ']
# ['Dorset', 'England.']
# ['Liverpool', 'England']
# ['New York', 'USA']
# [' London / Birmingham  UK ']
# ['London ']
# ['London town England North ']
# ['Wakefield', 'England']
# ['UK']
# ['Europe']
# ['Planet Earth - Occasionally ']
# ['Sheffield']
# ['Hell']
# ['Exeter']
# ['Bangor', 'Northern Ireland']
# ['EU']
# ['Wellington Region', 'Aotearoa']
# ['Hatfield', 'Hertfordshite']
# ['London', 'UK']
# ['Universal realm']
# ['Tāmaki Makaurau\n(Auckland)', 'NZ']
# ['Sevenoaks Kent']
# ['London', 'UK ']
# ['London']
# ['UK-THAILAND-SOUT KOREA']
# ['Madrid', 'Spain']
# ['On the border of life']
# ['England']
# ['Somewhere in England']
# ['wirral']
# ['Northern England    Pennines']
# ['Between London and DC. ']
# ['The Netherlands']
# ['Lancashire UK']
# ['Wales', 'United Kingdom']
# ['scotland ']
# ['Northern Ireland', 'United Kingdom']
# ['bromsgrove']
# ['United Kingdom']
# ['Birmingham', 'England']
# [' Dorset', 'Ireland', 'Colorado. ']
# ['UK']
# ['Lincolnshire', 'England']
# ['Kolkata', 'India']
# ['West Midlands', 'England']
# ['Hartlepool', 'England']
# ['Wales…Next to England ']
# ['Sunderland and Heacham Norfolk']
# ['Walkden', 'England']
# ['South East', 'England']
# ['London', 'England']
# ['United Kingdom']
# ['Madrid', 'Spain']
# ['London']
# ['London', 'United Kingdom']
# ['Sunny Surrey']
# ['Lincoln']
# ['England']
# ['Leeds england']
# ['Cornwall Uk']
# ['Europe']
# ['The World ']
# ['South West', 'England']
# ['Rio de Janeiro']
# ['London']
# ['north of the south pole']
# ['Glasgow']
# ['London']
# ['Saint-Jean-Cap-Ferrat']
# ['Somewhere over the rainbow']
# ['Scotland', 'United Kingdom']
# ['Guildford', 'England']
# ['United Kingdom']
# ['Hall Green', 'Birmingham']
# ['Brighton & Hove']
# ['Ireland']
# ['Auckland', 'New Zealand']
# ['London ']
# ['birmingham']
# ['NW England & IOM']
# ['IPCC Trumpton Camberwick Green']
# ['Boughton Monchelsea', 'England']
# ['England', 'United Kingdom']
# ['Thames Valley']
# ['UK']
# ['Ireland']
# ['Victoria', 'British Columbia']
# ['Near the beach', 'New Jersey']
# ['Scotland', 'United Kingdom']
# ['New York', 'USA']
# ['UK']
# ['Stoke-on-Trent', 'England']
# ['Salisbury', 'England']
# ['uk']
# ['England', 'United Kingdom']
# ['United Kingdom']
# ['Mablethorpe', 'England']
# ['Bedfordshire', 'England ']
# ['Kilpatrick', 'Scotland']
# ['London']
# ['Liverpool']
# ['Brighton']
# ['Maryland', 'USA']
# ['Portsmouth', 'UK ']
# ['England', 'United Kingdom']
# ['England', 'United Kingdom']
# ['Belfast', 'United Kingdom']
# ['Manchester', 'UK']
# ['Brooklyn', 'NY']
# ['United Kingdom']
# ['Cwmbran - South Wales']
# ['Madrid', 'Spain']
# ['Rural Kent', 'middle of nowhere']
# ['CA']
# ['Code: VENIALSPORE #ad']
# ['UK']
# ['Bolton', 'Lancashire ']
# ['Gloucestershire']
# ['London', 'England', 'UK']
# ['North East', 'England']
# ['Brighton']
# ['Nottingham', 'England']
# ['New York', 'USA']
# ['Liverpool', 'England']
# ['Cornwall', 'England']
# ['Southeast London']
# ['Somerset']
# ['South East', 'England']
# ['Man cave ']
# ['Great Urswick Cumbria ']
# ['Kristiansand']
# ['Lancaster', 'UK']
# ['Hampshire']
# ['Coventry', 'UK']
# ['Huddersfield', 'England']
# ['United Kingdom']
# ['Ayrshire']
# ['Spring', 'TX']
# ['Dundee', 'Perth', 'Angus & NE Fife']
# ['London', 'England']
# ['Alcatraz ']
# ['Aberdeen', 'Scotland']
# ['Englewood', 'FL']
# ['United Kingdom']
# ['Inverness', 'Scotland']
# ['United Kingdom']
# ['Birmingham', 'England']
# ['Hull']
# ['Glasgow', 'Scotland.']
# ['London', 'Fort Lauderdale Miami ']
# ['Paris']
# ['Manchester', 'England']
# ['Wherever I happen to be']
# ['Magilligan', 'County Derry', 'NI']
# ['United Kingdom']
# ['Dubai', 'United Arab Emirates']
# ['Burnley', 'Lancashire']
# ['Banbury', 'England']
# ['UK :United_Kingdom:']
# ['Wales']
# ['Wolverhampton']
# ['Proud Mancunian']
# ['Out and about']
# ['London', 'England']
# ['UK']
# ['England']
# ['Devon']
# ['Nottinghamshire', 'UK']
# ['England ']
# ['United Kingdom']
# ['International']
# ['Kenya']
# ['Ghana']
# ['Emirates Stadium']
# ['Rugby', 'Warwickshire']
# ['Calgary', 'Canada']
# ['Birmingham']
# ['UK']
# ['MANCHESTER']
# ['Ashton under Lyne ']
# ['London / On the road']
# ['Cloud 9 ']
# ['UK']
# ['Kansas', 'USA']
# ['UK']
# ['Belfast', 'Northern Ireland']
# ['United Kingdom']
# ['Belfast', 'Northern Ireland']
# ['Surrey']
# ['London', 'England']
# ['Derry via Ballyshannon ']
# ['cambridgeshire']
# ['Omaha', 'Nebraska']
# ['Earth']
# ['United Kingdom']
# ['Boston', 'MA.']
# ['Germany']
# ['Hemsworth West Yorkshire']
# ['WIMBLEDON']
# ['England', 'United Kingdom']
# ['West Midlands', 'England']
# ['London', 'England']
# ['England and Wales']
# ['On the Path to Contentment']
# ['Belfast', 'Northern Ireland']
# ['Nottingham']
# ['England']
# ['Sussex UK']
# ['LDN']
# ['Canterbury', 'UK']
# ['England', 'United Kingdom']
# ['The World']
# ['Wilton Cork City Ireland']
# ['Out here.. somewhere!']
# ['United Kingdom']
# ['UK']
# ['London']
# ['London', 'England']
# ['London', 'Chelmsford England', 'UK']
# ['丅ᕼᗴ ᗯᗩᒪᒪᗩᑕᗴ ᑕᗝᖇᑭᗝᖇᗩ丅Iᗝᑎ']
# ['Brighton and Hove', 'UK']
# ['London', 'England']
# ['Brighton', 'UK']
# ['No Lists Please. #Blocked']
# ['Woking', 'Surrey ']
# ['Greenock', 'Scotland']
# ['London', 'England']
# ['Lisbon - Portugal']
# ['751516./sh×']
# ['Iowa']
# ['LONDON', 'ESSEX']
# ['United Kingdom']
# ['Cambridgeshire England']
# ['South East', 'England']
# ['Moray']
# ['United Kingdom']
# ['Perry', 'Birmingham', 'Gaia']
# ['England.']
# ['Lancashire']
# [' Yorkshire']
# ['London']
# ['Scotland', 'UK']
# ['Isle of Wight', 'England']
# ['Warrington', 'Cheshire']
# ['England', 'United Kingdom']
# ['Washington D.C']
# ['London']
# ['The Weald,Cranbrook,Kent,UK']
# ['England', 'United Kingdom']
# ['London', 'England']
# ['Somerset ', 'England']
# ['Madrid', 'Spain']
# ['London UK']
# ['Canterbury', 'England']
# ['Oxfordshire']
# ['skipton']
# ['Manchester', 'England']
# ['London']
# ['Manchester', 'England']
# ['London']
# ['Guildford England']
# ['London', 'England']
# ['South East', 'England']
# ['North West', 'England']
# ['England', 'United Kingdom']
# ['UK']
# ['Disunited Kingdom']
# ['London']
# ['London', 'England']
# ['United Kingdom']
# ['Hove', 'England']
# ['world citizen']
# ['UK']
# ['Perpignan', 'France']
# ['West Yorkshire ']
# ['United Kingdom']
# ['Scotland (But Defos Moscow)']
# ['United States']
# ['Stockholm', 'Sweden']
# ['Dublin']
# ['London']
# ['Cloud']
# ['Los angeles', 'ca.']
# ['London ']
# ['Devon. England']
# ['London', 'England']
# ['Yorkshire']
# ['Neverland ']
# ['Eastbourne', 'England']
# ['Horsham', 'West Sussex']
# ["God's Own County 'Yorkshire':folded_hands:"]
# ['Hampshire']
# ['The Gold Coast']
# ['Dinosaur']
# ['Ilford essex']
# ['London', 'England']
# ['Ireland']
# ['South West England', 'UK']
# ['Dulwich Village']
# ['Gaerwen', 'Wales']
# ['Guardian']
# ['London', 'England']
# ['London', 'UK']
# [':Ireland:']
# ['London', 'LA', 'Austin Texas']
# ['WORLD']
# ['United Kingdom']
# ['D144 Marine Quarters', 'Warri', '']
# [':sparkling_heart::United_Kingdom:전주시,UK Surrey:United_Kingdom::sparkling_heart:']
# ['Crawley', 'South East']
# ['Mandaue City', 'Central Visayas']
# ['California']
# ['England', 'UK']
# ['#RealBritain']
# ['Planet Earth']
# ['Sussex', 'South East', 'England']
# ['ethers']
# ['United Kingdom']
# ['Lagos']
# ['Grimsby', 'England']
# ['Blackburn']
# ['Greece']
# ['Brighton']
# ['United States']
# ['London']
# ['Normal', 'IL']
# ['New Delhi', 'India']
# ['Yorkshire England']
# ['London', 'England']
# ['England', 'United Kingdom']
# ['London', 'Edinburgh & Belfast']
# ['Brighton']
# ['Linlithgow', 'Scotland']
# ['Cardiff', 'Wales']
# ['Brighton']
# ['Chesham', 'South East']
# ['Quelque part en France :winking_face:']
# ['Rio de Janeiro', 'Brasil']
# ['Sunny South Coast']
# ['West Midlands', 'England']
# ['UK']
# ['Tillicoultry', 'Scotland']
# ['Kitchener', 'ON ']
# ['Back in the Vitalik basement']
# ['London']
# ['making tea']
# ['Around the World :globe_showing_Europe-Africa::globe_showing_Americas:']
# ['Brighton & Hove']
# ['Somewhere in the Mitten', 'USA']
# ['Lagos', 'Nigeria']
# ['London']
# ['Plague Island ']
# ['South Tipperary', 'Ireland']
# ['Sittingbourne']
# ['London']
# ['East', 'England']
# ['Angus ']
# ['Birmingham']
# ['no where in particular']
# ['@MediaWeasel@mastodon.scot']
# ['Northeast USA']
# ['Basingstoke']
# ['Middleton on sea ']
# ['England ']
# ['Joinville', 'Santa Catarina ']
# [' Broken Britain ']
# ['Dallas', 'Texas']
# ['UK']
# ['Bexhill', 'England', 'EUROPE.']
# ['Sunderland', 'England']
# ['Here and mostly here.']
# ['God’s county Yorkshire ']
# ['The North:up_arrow:️']
# ['Norwich', 'England']
# ['Greater Manchester', 'England']
# ['g']
# ["'tween Cosmos and  Ether"]
# ['MUKONO ']
# ['Lebanon']
# ['Surrey', 'United Kingdom']
# ['England', 'United Kingdom']
# ['Dublin']
# ['North Carolina & SW5 London UK']
# ['Dar es Salaam', 'Tanzania']
# ['Leeds/Manchester/Skipton']
# ['Birmingham']
# ['United Kingdom']
# ['Sheffield', 'England']
# ['Eastbourne', 'England']
# ['Kent. The UK.']
# ['My House']
# ['Brighton', 'England']
# ['Leaving the Earth']
# ['Republic of Texas']
# ['Fort Worth', 'TX']
# ['Zaria', 'Nigeria']
# ['United Kingdom']
# ['Wrotham Heath', 'Kent']
# ['SIN CITY']
# ['Chicago', 'Il.']
# ['Manchester', 'England']
# ['Lewisham', 'London']
# ['West Yorkshire']
# ['SHOPIAN Kashmir']
# ['EU :European_Union:']
# ['United Kingdom']
# ['Wappingers Falls', 'NY']
# ['Narnia ']
# ['uk']
# ['Farnham', 'Surrey', 'England']
# ['USA']
# ['Stoke-on-Trent']
# ['United Kingdom']
# ['Arizona', 'USA']
# ['En la tierra de Cervantes']
# ['宮城 石巻市']
# ['United Kingdom']
# ['Cambs', 'London', 'S E Asia']
# ['Niigata', 'Japan']
# ['Osun', 'Nigeria']
# ['New Guinea']
# ['Birmingham', 'England']
# ['19', 'she/her']
# ['USA']
# ['The Æther']
# ['Siglo de oro', 'España']
# ['London', 'England']
# ['UK']
# ['London', 'UK']
# ['Everton fan :blue_heart:']
# ['here ']
# ['United States,Taos']
# ['Earth']
# ['London ']
# ['Wales', 'United Kingdom']
# [':sparkling_heart::United_Kingdom:전주시,UK Surrey:United_Kingdom::sparkling_heart:']
# ['Coventry', 'England']
# ['Cardiff', 'South Wales']
# ['Kiama']
# ['Blackpool']
# ['Largs', 'Scotland']
# ['Highly skilled professional ']
# ['she/her']
# ['Toronto Canada']
# ['Kent', 'England']
# ['plymouth']
# ['England', 'United Kingdom']
# [':elephant: ']
# ['Durham', 'England']
# ['London ']
# ['watford', 'herts']
# ['England', 'United Kingdom']
# ['Ludington MI home town']
# ['Dublin', 'Ireland']
# ['Dallas', 'TX']
# ['Surrey UK']
# ['Chattanooga', 'TN', 'USA']
# ['Ewyas Harold ']
# ['Steven Spielberg Psych Hos.']
# ['Herts boy now in salford']
# ['Bournemouth', 'England']
# [':Canada:']
# ['London']
# ['Rutland', 'England']
# ['Pennsylvania.EastSyyyyyyyyde']
# ['Rhondda']
# ['Essex']
# ['now in Atlanta via NYC']
# ['Pakistan']
# ['The World']
# ['Michigan', 'USA']
# ['https://www.instagram.com/p/CD']
# ['Essex']
# ['London', 'England']
# ['Ampang']
# ['Huddersfield', 'England']
# ['London']
# ['Royal Tunbridge Wells', 'England']
# ['Your Fragile Ego']
# ['UK']
# ['Dudley', 'West Midlands']
# ['East Midlands', 'England']
# ['Service Is Universal:elephant::globe_showing_Europe-Africa::globe_showing_Americas::globe_showing_Asia-Australia::elephant:']
# ['Pennsylvania', 'USA']
# ['East Midlands', 'England']
# ['USA']
# ['Isle of Wight UK']
# ['Whatever']
# ['East', 'England']
# ['Republic of Mancunia']
# ['Leeds', 'England']
# [':Nigeria: ~ lds • ldn | med student']
# ['Cloud']
# ['Norfolk. England.']
# ['U.K.']
# ['New Jersey']
# ['Rugby', 'England']
# ['London']
# ['इंद्रप्रस्थ विदेह पाटलिपुत्र ']
# ['London']
# ['United States']
# ['Cheshire', 'UK']
# ['London...']
# ['London', 'UK']
# ['Glasgow environs.']
# ['Some dump in N.Somerset', 'UK ']
# ['Boston,Mass']
# ['Langley', 'Berkshire']
# ['Falmouth', 'England']
# ['UK']
# ['Earth']
# ['Great Whin Sill']
# ['swimming with the sirens']
# ['london']
# ['A Scot now living in Southsea']
# ['World']
# ['South Wales Valleys:black_flag:\U000e0067\U000e0062\U000e0077\U000e006c']
# ['Tappham-on-the-Nose', 'England']
# ['Scotland', 'United Kingdom']
# ['Ex London now North Wales']
# ['North West', 'England']
# ['Manchester', 'England ']
# ['Hounslow', 'London']
# ['New Zealand']
# ['London', 'England']
# ['gauteng']
# [':Wales::United_Kingdom::European_Union::globe_showing_Europe-Africa:']
# ['Manchester', 'England']
# ['Location? Behind you.']
# ["Cornwall   I don't answer DM's"]
# ['Peterborough']
# ['UK']
# ['Smallville/Metropolis ']
# ['UK & international']
# ["Sadiq Khan's Personal Fiefdom"]
# ['East Wickham / Woolwich']
# ['Ellon', 'Scotland']
# ['London', 'England']
# ['London', 'England']
# ['Andover']
# ['Basingstoke', 'England']
# ['Romsey', 'England']
# ['France']
# ['Weymouth', 'England']
# ['Cambridge']
# ['London/Tallinn + elsewhere']
# ['Constitution First Amendment']
# ['Devon', 'UK']
# ['Blyth', 'England']
# ['Coventry', 'England']
# ['Eating puff puff']
# ['Glenham', 'NY']
# ['United Kingdom']
# ['Europe']
# ['Muswell Hill', 'London', 'England']
# ['London']
# ['Manila City', 'National Capital ']
# ['European Union :European_Union:']
# ['London ', 'and Surrey']
# ['England', 'United Kingdom']
# ['Greenville', 'TX']
# ['Vinirishsays']
# ['Halifax / Todmorden', 'UK']
# ['Terf Island ']
# ['Wales', 'United Kingdom']
# ['Woodbridge', 'England']
# ['Behind you']
# ["shrek's swamp"]
# ['Norway']
# ['Nigeria']
# ['London']
# ['United Kingdom']
# ['Leamington Spa', 'England']
# ['Southsea', 'United Kingdom']
# ['W3103']
# ['Wales ']
# ['seville']
# ['Universe']
# ['East', 'England']
# ['Kolkata']
# ['WORLDWIDE']
# ['ÜT: 51.371278,-0.116717']
# ['London']
# ['Yorkshire and The Humber', 'England']
# ['East', 'England']
# ['Scotland']
# ['Greenock', 'Scotland']
# ['London']
# ['North Yorkshire']
# ['Spiritually', '1970’s Dublin ']
# ['Hythe', 'England']
# ['Hell']
# ["foot o' t'pennines"]
# ['Ireland']
# ['LAS']
# ['Witness Protection']
# ['UK']
# ['Washington', 'D.C.']
# ['Reading']
# ['East Yorkshire']
# ['Scotland']
# ['Birmingham ']
# ['Swindon', 'Wiltshire']
# ['York', 'England']
# ['England', 'United Kingdom']
# ['Switzerland']
# ['north Yorkshire.  UK']
# ['plague island 346ppm']
# ['Londonshire']
# ['Maidstone', 'South East']
# ['TERF island']
# ['Everywhere']
# ['rig patform - veslefrikk']
# ['Inverness', 'Scotland']
# ['United Kingdom']
# ['Gotham City']
# ['Barking and Dagenham']
# ['mars or may as well be. ']
# ['United Kingdom']
# ['London Borough of Newham']
# ['Islington']
# ['Hackney']
# ['Liverpool', 'England']
# ['Scotland', 'United Kingdom']
# ['Ilford', 'Redbridge']
# ['East London']
# ['Stockton-on-Tees', 'England']
# ['LLandudno', 'North Wales.']
# ['United Kingdom']
# ['England', 'United Kingdom']
# ['South Dakota', 'USA']
# ['Great Britain']
# ['Liverpool', 'UK/Manchester', 'UK']
# ['United Kingdom']
# ['Glossop']
# ['uk']
# ['London']
# ['Amsterdam', 'Nederland']
# ['Hannover']
# ['Wokingham']
# ['Middle of soggy island', 'Earth']
# ['Ireland']
# ['Sha Tin', 'Republic of Hong Kong']
# ['Bournemouth']
# ['Gulag of Washington state ']
# ['Megan :red_heart:️.  lochgelly ']
# ['LondonCity.']
# ['United States']
# ['London', 'England']
# ['Europe']
# ['Dunfermline', 'Scotland']
# ['London']
# ['Leeds', 'England']
# ['Brick Lane']
# ['London', 'England']
# ['Somerton', 'UK']
# ['Hammersmith', 'London']
# ['UK']
# ['Stirling', 'Scotland']
# ['Manchester']
# ['London', 'England']
# ['Preston']
# ['Waterfoot', 'Scotland']
# ['London']
# ['London']
# ['Raleigh NC']
# ['Hampshire UK']
# ['Bellshill,North Lanarkshire']
# ['United Kingdom']
# ['Suffolk', 'England']
# [' Florida Jacksonville Glen St,']
# ['Norway  :Norway::people_hugging:']
# ['London', 'England']
# ['United States']
# ['Manchester']
# ['London', 'England']
# ['Wakanda']
# ['San Diego', 'California']
# ['United Kingdom']
# ['United Kingdom']
# ['Everywhere']
# ['Coast UK']
# ['ENGLAND']
# ['If you need freelance PR or media advice at reasonable rates', 'DM me. https://www.linkedin.com/in/raffy-hamid-771b8566/']
# ['United Kingdom']
# ['bristol uk']
# ['edinburgh scotland ']
# ['Nairobi', 'Kenya ']
# ['Marshall Heights', 'Washington']
# ['East Sussex England UK']
# ['Umhlanga', 'South Africa']
# ['Breaking News everywhere']
# ['UK']
# ['England', 'United Kingdom']
# ['in Queensland']
# ['Illinois']
# ['England', 'AR']
# ['Batti Village The Gambia & UK']
# ['Glasgow']
# ['Arnhem', 'The Netherlands']
# ['London']
# ['“European Union :European_Union:”.']
# ['New York / fb.com/nydailynews']
# ['Wales', 'United Kingdom']
# ['Earth']
# ['Ghana']
# ['Weymouth England']
# ['London']
# ['United Kingdom']
# ['Pennsylvania', 'USA']
# [':new_moon_face:']
# ['Australia']
# ['Essex']
# ['Global']
# ['Kansas City', 'MO']
# ['N Ireland']
# ['Rick McCann Police Chief/FF-EMT/Chaplain/Author']
# ['Georgia', 'USA']
# ['California', 'USA']
# ['Devon', 'England.']
# ['Philadelphia', 'PA']
# ['Heartland']
# ['Citizen of Nowhere']
# ['New York', 'USA']
# ['Dublin', 'Ireland']
# ['Happy place']
# ['Danang', 'Vietnam']
# ['UK']
# ['Miami', 'FL']
# ['The HoloSphere', '']
# ['London UK']
# ['Piedmont Triad', 'North Carolina']
# ['Reading', 'UK']
# ['São José do Rio Preto']
# ['UK']
# ['Perth', 'Western Australia']
# ['California', 'USA']
# ['Toronto']
# ['Ireland']
# ['Dublin']
# ['Viena', 'Austria']
# ['Salinas', 'CA']
# ['West midland U.K. ']
# ['United Kingdom']
# ['South Staffs']
# ['St Albans England']
# ['Any warm lap']
# ['Canada']
# ['North Las Vegas', 'NV']
# ['Chimbote', 'Peru :Peru:']
# ['Global']
# ['Right Wingshire UK ']
# ['UK']
# ['England']
# ['Near Skinners Bottom Cornwall']
# ['United Kingdom']
# ['England']
# ['earth']
# ['New York City to Palm Beach']
# ['Gulf Coast ']
# ['London']
# ['Texas']
# ['North East', 'England']
# ['Leicester']
# ['London via Venus']
# ['Liverpool UK']
# ['Manchester']
# ['Right Here usually. ']
# ['Kampala', 'Uganda']
# ['England']
# ['weirdly', 'a house near the sea']
# ['A Good Place']
# ['Brighton', 'England']
# ['Portadown', 'Northern Ireland']
# ['sac town']
# ['Nottingham', 'England']
# ['Glasgow', 'Scotland']
# ['Oxfordshire']
# ['Ontario', 'Canada']
# ['Leeds', 'England']
# ['Stockport', 'England']
# ['Newcastle', 'UK']
# ['bolton']
# ['England', 'United Kingdom']
# ['NANAIMO BC CANADA']
# ['On another Level']
# ['Haslemere', 'England']
# ['London']
# ['Beddington North']
# ['Kensington & Chelsea', 'London ']
# ['Somewhere in Bonnie Scotland']
# ['Manchester', 'UK']
# ['London', 'England']
# ['Somewhere on planet Earth']
# ['Canada']
# ['United Kingdom', 'Africa']
# ['Cherokee National Forest,TN/NC']
# ['Johnson City', 'TN']
# ['BRADFORD UK']
# ['UK']
# ['Brighton']
# ['Torbay', 'England']
# ['London Kent Spain ']
# ['Southport', 'England']
# ['New York', 'NY']
# ['Berkshire- UK']
# ['manhattan']
# ['Norfolk ']
# ['USA']
# ['NAFO USA']
# ['USA and the world']
# ['München']
# ['DMV', 'United States']
# ['South West', 'England']
# ['Ireland']
# ['West London', 'UK ']
# ['Leeds', 'England']
# ['London', 'UK']
# ['Tewkesbury', 'England']
# ['Republic of Wales']
# ['Scotland', 'United Kingdom']
# ['calgary']
# ['England', 'United Kingdom']
# ['Brighton', 'UK']
# ['Cornwall', 'UK']
# ['Snowdonia ']
# ['New Zealand']
# ['universal/up north/fuck tories']
# ['London', 'England']
# ['Brighton', 'England']
# ['WooPigSooie Razorback Country ']
# ['Jackson', 'MS']
# [':United_Kingdom: SW and NE  ']
# ['Torbay UK ']
# ['Gloucestershire.']
# ['Harrogate', 'England']
# ['Dublin City', 'Ireland']
# ['London - United Kingdom \uea00']
# ['Pakistan']
# ['England :United_Kingdom:Guinea:Guinea:']
# ['Canada']
# ['London', 'England']
# ['York', 'England']
# ['London', 'England']
# ['Glasgow', 'Scotland']
# ['Patna', 'Scotland']
# ['USA']
# ['North East', 'England']
# ['Planet Earth :globe_showing_Europe-Africa:']
# ['London', 'England']
# ['United States']
# ['Fachbach und Büchen']
# ['Dersingham (obviously)']
# ['Langley VA + MI6 + GCHQ :smiling_face_with_sunglasses:']
# ['San Antonio', 'TX']
# ['United States']
# ['England', 'United Kingdom']
# ['England']
# ['Manchester', 'England']
# ["Devil's Island"]
# ['london']
# ['Liverpool', 'England']
# ['Wyoming,usa']
# ['Lancashire']
# ['Devon', 'UK']
# ['Castle of Infinity']
# ['Manchester ']
# ['Canada']
# ['Penarth']
# ['Lost in Space.']
# ['United Kingdom']
# ['Scotland']
# ['middlesbrough. ']
# ['Midlands UK. ']
# ['London']
# ['United States']
# ['Bristol', 'England']
# ['Maryland', 'USA']
# ['England West Yorkshire']
# ['Australia/India']
# ['Tiohtià:ke / Montréal  :Canada:']
# ['Islington', 'London']
# ['Boston', 'MA']
# ['Wigtownshire via Llanedi']
# ['Manchester', 'England']
# ['London', 'England']
# ['England', 'United Kingdom']
# ['North West', 'England']
# ['California', 'USA']
# ['Barry ']
# ['New York', 'New York']
# ['Florida', 'USA']
# ['Scunthorpe', 'England']
# ['England']
# ['Zurich']
# ['Eastern Region']
# ['Anniston', 'AL']
# ['South Warks']
# ['Ireland']
# ['United States']
# ['Washington', 'D.C.']
# ['من:Saudi_Arabia: العظمى حسابي رجع:waving_hand_light_skin_tone:   ']
# ['Indiana', 'USA but Brooklyn NY ']
# ['United Kingdom']
# ['???']
# ['Enjeni aka South Africa ']
# ['New York City']
# ['Australia ']
# [':globe_showing_Americas:']
# ['Tustin', 'CA']
# ['Selkirkshire']
# ['Burlington,Ontario']
# ['Ely']
# ['Huntingdon', 'England']
# ['In Your Heart']
# ['Tampa']
# ['The Kingdom of Fife', 'Alba']
# ['Leeds', 'England']
# ['People’s Republic of Anhedonia']
# ['Portland', 'Oregon', 'USA']
# ['Your head (rent-free)']
# ['Eluru', 'India']
# ['London']
# ['March']
# ['Wisbech', 'Cambridgeshire']
# ['London', 'England']
# ['Wigan', 'England']
# ['North Carolina', 'USA']
# ['Fife', '']
# ['أبوظبي', 'الامارات العربية المتح']
# ['Dominican Republic']
# ['Tier 9', 'Brexshitshire', 'UK']
# ['Philadelphia', 'PA']
# ['USA']
# ['USA']
# ['In the city you hated']
# ['Virginia', 'USA']
# ['Lagos', 'Nigeria']
# ['Everywhere']
# ['UK', 'USA', 'Malaysia & Australia.']
# ['Paris', 'France']
# ['uk']
# ['Nigeria']
# ['Kidgeon Pickerland']
# ['Tanzania']
# ['United Kingdom']
# ['Bell Gardens/Pasadena']
# ['Sunny Manchester', 'England']
# ['Nomadic']
# ['London']
# ['Regina', 'Saskatchewan']
# ['Somewhere by the Great Lakes']
# ['UK']
# ['Goiânia', 'Brazil']
# ['Ontario', 'Canada']
# ['e17']
# ['Gatineau', 'Québec']
# ['London']
# ['Australia']
# ['Somewhere:yawning_face:']
# ['Leicester', 'England']
# ['Unstable...']
# ['Hertfordshire']
# ['FL (Where woke goes to die)']
# ['King Kai’s Planet']
# ['Everywhere']
# ['Glasgow']
# ['Wales', 'United Kingdom']
# ['NW Cheshire:United_Kingdom: ']
# ["London'Child "]
# ['UK']
# ['England', 'United Kingdom']
# ['London']
# ['Belfast ardoyne']
# ['Liverpool', 'England']
# ['New Forest']
# ['Peoples Republic of Liverpool ']
# ['Deptford']
# ['England', 'United Kingdom']
# ['Home visits&gigs anywhere']
# ['Terf Island ']
# ['Manchester ']
# ['Darlington', 'England']
# ['Brighton ']
# ['United Kingdom']
# ['Newcastle']
# ['United Kingdom']
# ['Overland Park', 'KS']
# ['UK Based']
# ['West Suffolk']
# ['UK']
# ['Somerset UK']
# ['Christchurch NZ']
# ['In the 1980s']
# ['Where ever my wheels are!']
# ['Newcastle via Hull']
# ['The Blue Dot']
# ['UK']
# ['Birmingham', 'England']
# ['London', 'England']
# ['West Midlands', 'England']
# ['Lake District via Birmingham']
# ['Florida immigrating to UK ']
# ['London']
# ['United Kingdom']
# ['Heaven Bound']
# ['Ottawa/Glasgow']
# ['Atlanta', 'GA']
# ['London', 'UK']
# ['London ']
# ['redcar']
# ['Bradford']
# ['Cambridgeshire', 'UK']
# ['Manton', 'North Lincs']
# ['UK']
# ['Wales', 'United Kingdom']
# ['Lincolnshire ']
# ['North West', 'England']
# ['England', 'United Kingdom']
# ['Plymouth', 'England']
# ['Venus']
# ['Long Sutton Lincs']
# ['Manchester', 'UK']
# ['NE Illinois (not chicago)']
# ['Glasgow ']
# ['London', 'England']
# ['All over the world ']
# ['Chester', 'England']
# ['united kingdom']
# ['Hampshire', 'UK']
# ['Midstream', 'South Africa']
# ['Penryn', 'England']
# ['Glasgow', 'Scotland']
# ['Hutchinson', 'MN']
# ['Bury St Edmunds', 'Suffolk', 'UK']
# ['Wolverhampton', 'England']
# ['Durham', 'England']
# ['Birmingham-where-else']
# ['Bedford Falls']
# ['Cape Town']
# ['Manchester']
# ['Herts']
# ['Yorkshire/ Ireland', 'depending']
# ['England', 'United Kingdom']
# ['Yenevelt']
# [':United_Kingdom:']
# ['York']
# ['Westgate on Sea']
# ['Nowhere']
# ['Paisley', 'Scotland']
# ['England']
# ['Southend Essex ']
# ['Cottonopolis - UK - :green_heart::honeybee::green_heart:']
# ['Grangemouth', 'Scotland']
# ['Chesterfield', 'England']
# ['Glasgow']
# ['London (via West Virginia)']
# ['East Sussex']
# ['London innit?']
# ['North Wales', 'UK ']
# ['London', 'England']
# ['Leeds']
# ['England', 'United Kingdom']
# ['Wales']
# ['United Kingdom']
# ['Wales', 'United Kingdom']
# ['', 'london']
# ['地球']
# ['England']
# ['Bed,probably(Devon,England):person_in_bed:']
# ['Glenrothes', 'Scotland']
# ['Plague Island']
# ['Manchester', 'England']
# ['Humanity']
# ['London_ish']
# ['Punjab', 'Pakistan']
# ['London', 'England']
# ['Liverpool UK no group chats']
# ['Sevenoaks or chasing the sun:sun:️']
# ['brighton']
# ['London', 'England']
# ['Dùn Dè']
# ['Soho • Mayfair • Walthamstow ']
# ['Poitou-Charentes', 'France']
# ['Sussex', 'UK']
# ['North West', 'England']
# ['Wales']
# ['Birmingham', 'England']
# ['United Kingdom']
# ['None of your business ']
# ['Brisbane', 'Queensland']
# ['Worcester', 'England']
# ['Consultio/Consultius']
# ['Scotland ']
# ['London ']
# ['Yorkshire']
# ['United Kingdom']
# ['North London', 'England']
# ['Swansea']
# ['Hull', 'England']
# ["Shanghai'd In Shanghai "]
# ['United Kingdom']
# [':Kenya::United_Kingdom:']
# ['Rugby Office']
# ['Louisville', 'KY']
# ['Black Isle', 'Highland Scotland ']
# ['Nottinghamshire']
# ['London To Lagos']
# ['the beautiful north']
# ['Southrepps', 'England']
# ['Uk']
# ['Lincolnshire UK']
# ['Europe']
# ['Ontario']
# ['Scotland', 'United Kingdom']
# ['Wyndemere']
# ['Harare', 'Zimbabwe.']
# ['Reading', 'England']
# ['Brighton', 'England']
# ['Birmingham', 'England']
# ['Northern Ireland', 'United Kingd']
# ['Greenwich Peninsula', 'London']
# ['England']
# ['South West', 'England']
# ['Loughborough', 'England']
# ['Glasgow']
# ['Cymru']
# ['Knutsford', 'Cheshire']
# ['Teesside ']
# ['London', 'England']
# ['London']
# ['Fleet', 'Hampshire', 'England UK']
# ['Kekistan']
# ['Sitting on the stoop']
# ['Nomad']
# ['Ireland']
# ['Verdansk']
# ['London/Dublin/Denmark/Belfast']
# ['Shaftesbury', 'England']
# ['Rural Staffs (UK)']
# ['Derby', 'England via Tanelorn ']
# ['England', 'United Kingdom']
# ['London', 'England']
# ['Manchester', 'England']
# ['London', 'England']
# ['Edinburgh']
# ['Essex']
# ['Eastbourne', 'England']
# ['Ireland']
# ['Ashford ']
# ['Ireland.']
# ['London', 'England']
# ['London', 'England']
# ['London', 'England']
# [':globe_showing_Americas: Earth']
# ['Yarm']
# ["Connah's Quay", 'Wales']
# ['North Northumberland']
# ['Toronto', 'Ontario']
# ['Basildon', 'Essex', 'England']
# ['London/Kent', 'England probably ']
# ['Brighton', 'England']
# ['The Streets', 'Muslamanie ']
# ['Belfast']
# ['Ellon', 'Scotland']
# ['Sutton', 'London']
# ['London']
# ['Somewhere lost in time']
# ['Kildare', 'Ireland']
# ['Crapsville']
# [':European_Union: ']
# ['Narnia. ']
# ['Hereford', 'UK']
# ['Brighton', 'England']
# ['London']
# ['Nicosia']
# ['Merseyside', 'UK']
# ['Newcastle-under-Lyme']
# [':globe_showing_Americas:']
# ['Curnow England']
# ['Kent', 'UK']
# ['Argyll & Bute', 'Scotland']
# ['United Kingdom']
# ['Scotland', 'United Kingdom']
# ['The Hood Called Woman ']
# ['Derby', 'England']
# ['United Kingdom']
# ['Hants']
# ['Manchester', 'England']
# ['London']
# ['London']
# ['land of the fae']
# ['Somewhere']
# ['South Wales']
# ['Hoodickey House', '61.8 Germane Avenue', ' Glean City', 'Gooberville.Or just mail the writ to: #S.A.L.I.E.N.T - P.O.I.N.T']
# ['Manchester', 'England']
# ['Preston', 'England']
# ['Liverpool (UK)']
# ['Mars']
# ['Los Angeles', 'CA']
# [' Wales uk']
# ['England', 'United Kingdom']
# ['Portishead', 'England']
# ['United Kingdom']
# ['Essex']
# ['firetop mountain wales']
# ['Manchester', 'England']
# ['London', 'England']
# ['Sligo', 'Ireland']
# ['United States']
# ['uk']
# ['Cheshire']
# ['Teesside', 'UK']
# ['Teesside']
# ['England ']
# ['Callay,Northumberland']
# ['in a world of my own']
# ['Liverpool', 'England']
# ['East Whitburn  ']
# ['Birmingham', 'England B45']
# ['Gosport']
# ['Londongrad', 'England']
# ['United Kingdom']
# ['Everywhere and nowhere baby']
# ['Essex']
# ['London']
# ['Darlington England']
# [' Northamptonshire UK']
# ['Bromley', 'London']
# ['Cornwall UK ']
# ['Northern Ireland']
# ['Northern Ireland']
# ['By The Sea...']
# ['CEO and Managing Director']
# ['United Kingdom ']
# ['Northern Ireland']
# ['London']
# ['Horsham Sussex']
# ['Wales & Cornwall']
# ['United Kingdom']
# ['central mainland']
# ['In the Shires']
# ['Belgae :Wales::United_Kingdom:']
# ['On The Dark Side']
# ['UK']
# ['Welsh valleys']
# ['Crapston Villas', 'UK']
# ['Liverpool', 'England']
# ['United Kingdom']
# ['Cushendall']
# ['UK & PORTUGAL']
# ['Oxford', 'England']
# ['east anglia/east Midlands']
# ['Leeds']
# ['London', 'United Kingdom']
# ['Ireland', 'Earth.']
# ['newcastle upon tyne']
# ['The Ozarks ']
# ['Wales', 'United Kingdom']
# ['Ireland']
# ['Kidderminster']
# ['Sunny south coast']
# ['UK']
# [' England', 'Sheffield ']
# ['Edinburgh', 'Scotland']
# ['Portslade by Sea', 'UK']
# ['North Eastern region', 'Kenya ']
# ['Tottenham', 'London']
# ['a burning planet']
# ['United Kingdom']
# ['Leeds']
# ['East Kilbride', 'Scotland']
# ['Leamington Spa', 'England']
# ['Dublin City', 'Ireland']
# ['Inferno']
# ['Manchester', 'England']
# ['Redfern', 'Sydney']
# ['Yorkshire']
# ['Surrey']
# ['Kildare', 'Ireland']
# ['Manchester', 'England']
# ['England', 'United Kingdom']
# ['Liverpool', 'England']
# ['South West', 'England']
# ['West Midlands', 'England.']
# ['In a John Field Devon']
# ['Gateshead', 'England']
# ['North east sea coast']
# ['abbots Langley']
# ['Scotland']
# ['Denmark - Copenhagen North']
# ['England', 'United Kingdom']
# ['South East', 'England']
# ['Romsey,Hampshire']
# ['Stockton', 'UK']
# ['London']
# ['lakes district']
# ['South East', 'England']
# ['London', 'England']
# ['London', 'England']
# ['norfolk']
# ['London']
# ['Northern England ']
# ['London', 'England']
# ['Kent']
# ['Cumbria']
# ['HK', 'UK', 'IndoPac', 'Free World']
# ['Broughton', 'England']
# ['Wigan', 'England']
# ['In The Cloud ']
# ['Cabot Cove']
# ['London']
# ['London ']
# ['Sevenoaks', 'Kent', 'UK']
# ['London']
# ['Newcastle UK']
# ['London']
# ['South East', 'England', 'Hailsham.']
# ['221b Baker St. Paoli', 'PA.']
# ['Worldwide']
# ['Scotland ']
# ['North West', 'Great Britain']
# ['Barnsley', 'England']
# ['Scotland', 'United Kingdom']
# ['The Garden of England ']
# ['Bournemouth', 'England']
# ['London', 'England']
# ['London/Assyria :Iraq::Ireland:']
# ['Northern Ireland']
# ['Rhein-Erft-Kreis']
# ['Peak District / Alderley Edge']
# ['Manchester', 'England']
# ['Hyde uk.']
# ['South Devon']
# ['Planet Earth', 'Brexshit Island']
# ['United Kingdom']
# ['United Kingdom']
# ['Exeter']
# ['England ']
# ['Attiki', 'Greece']
# ['United Kingdom']
# ['London and Jurassic Coast']
# ['Qui Nhơn,Bình Định', 'Việt Nam']
# ['City of Southend-on-Sea']
# ['Connecticut', 'USA']
# ['somewhere in the world']
# ['England', 'United Kingdom']
# ['Pulaski', 'TN']
# ['England', 'United Kingdom']
# ['Sheffield', 'England']
# ['England']
# ['Manchester', 'United Kingdom']
# ['Jozi :South_Africa:']
# ['London and Devon']
# ['London ']
# ['South West', 'England']
# ['Wales', 'United Kingdom']
# ['In the Present Moment']
# ['The other end of the lead']
# ['London']
# ['Salt Lake City', 'Utah']
# ['Stockton-on-Tees', 'England']
# ['Camber', 'England']
# ['Liverpool', 'England']
# ['UK and beyond']
# ['W.A.T.P. uk']
# ['London / Newbury / GWR']
# ['Birmingham', 'England']
# ['Isle of Wight ']
# ['North East', 'England']
# ['Scotland', 'United Kingdom']
# ['Abuja', 'Nigeria']
# ['Mars']
# ['Sefton']
# ['Scotland']
# ['Terf Island ']
# ['Paisley Park in my heart ']
# ['Bristol', 'England']
# ['United Kingdom']
# ['Sidmouth', 'England']
# ['Brighton']
# ['Somewhere you’re not. ']
# ['Oxford']
# ['México.', 'Puebla']
# ['BigYard', 'Swimming Hole']
# ['Global Heights']
# ['Watford', 'Herts.... UK... ']
# ['Bedfordshire & Buckinghamshire']
# ['Nationwide']
# ['London']
# ['In a land of make believe.']
# ['Hertfordshire UK']
# ['South East', 'England']
# ['Luton United Kingdom']
# ['Bristol', 'England']
# ['London', 'UK']
# ['Wales']
# ['Eastbourne', 'U.K. ']
# ['UK']
# ['Cumbria']
# ['London', 'England']
# ['Alba gu bràth']
# ['Bradford', 'West Yorkshire']
# ['Buckingham Palace', 'London']
# ['London (Born in Brum) :Jamaica:']
# ['Sale Moor']
# ['Greece']
# ['birmingham']
# ['North Yorkshire']
# ['Drinking again....']
# ['UK']
# ['Live:東京のどこか。半径3キロの世界']
# ['Middlesbrough']
# ['London']
# [' ']
# ['Attiki', 'Greece']
# ['Northern Ireland', 'United Kingd']
# ['London']
# ['North East', 'England']
# ['Essex']
# ['Garden of England kent']
# ['Clydebank ']
# ['Leeds', 'England']
# ['København', 'Danmark']
# ['Parkland', 'FL']
# [' :crown: ROYAL :crown: BOROUGH :crown: ']
# ['London', 'England']
# ['arthostage.blogspot.com']
# ['UK']
# ['Wigan']
# ['Here and There']
# ['Preston/London']
# ['The Midlands...& beyond.']
# ['Belfast']
# ['london ']
# ['Isle of Wight :smiling_face_with_heart-eyes:']
# ...
# ['London']
# ['Scotland', 'United Kingdom']
# ['UK']
# ['Mad Rabbit Holes. Earth. ']
# ['London']
# ['West Yorkshire']
# ['West Kelowna', 'British Columbia']
# ['London']
# ['UK she/her']
# ['England', 'United Kingdom']
# ['Canada']
# ['varies']
# ['North Yorkshire', 'UK']
# ['southerner ']
# ['Liverpool']
# ['The thick of it']
# ['Carlisle']
# ['Yeadon']
# ['Nunya Biz-ness']
# ['Stroud']
# ['London', 'England']
# ['Christchurch', 'England']
# ['Boothill ,liverpool']
# ['Perth', 'Scotland']
# ['india']
# ['United Kingdom']
# ['Melbourne', 'Victoria']
# ['New York', 'USA']
# ['johannesburg']
# ['Midlothian Scotland ']
# ['Derby', 'UK']
# ['New York', 'NY']
# ['Sunderland']
# ['East Midlands', 'England']
# ['Gateshead', 'England']
# ['Middle England', 'UK']
# ['North Wales']
# ['Northamptonshire', 'UK']
# ['Washington', 'DC. ']
# ['New York']
# ['United Kingdom']
# ['Huntsville', 'AL']
# ['Indianapolis', 'IN']
# ['Hove']
# ['East Sussex. UK. ']
# ['Pennsylvania', 'USA']
# ['London']
# ['London', 'England']
# ['Brighton - England']
# ['United Kingdom']
# ['Northern Ireland', 'United Kingdom']
# [':United_Kingdom: United Kingdom :United_Kingdom:']
# ['Denmark']
# ['us']
# ['Sector 7G (south wales)']
# ['Bolton', 'England']
# ['Somerset', 'England OoooArr ']
# ['United Kingdom', 'Hertfordshire']
# ['oklahoma']
# ['England', 'United Kingdom']
# ['London']
# ['Essex UK']
# ['Cardiff', 'Wales']
# ['Vancouver Island #yyj']
# ['Old Portsmouth', 'England']
# ['London']
# ['U.S.A']
# ['London']
# ['England', 'United Kingdom :United_Kingdom: ']
# ['England ']
# ['Bedfordshire']
# ['The quantum realm']
# ['Walsall']
# ['Linthorpe ']
# ['Ramsbottom Lancashire ']
# ['Where Love and Beauty Lives']
# ['Wigan', 'England']
# ['United States']
# ['London', 'England']
# ['South East', 'England']
# ['South East', 'England']
# ['Northamptonshire']
# ['Toronto']
# ['Here .  ']
# ['At home']
# ['London', 'England']
# ['London', 'England']
# ['Essex']
# ['Islamabad', 'Pakistan']
# ['West Midlands', 'England']
# ['Brighton', 'England']
# ['London', 'UK']
# ['West Yorkshire', 'England']
# ['North East England']
# ['Northumberland,England :United_Kingdom:']
# ['3.1415926535 ']
# ['Suffolk United Kingdom']
# ['New York', 'NY']
# ['City of London', 'London']
# ['USA']
# ["Under These Bitches' Skin"]
# ['Phoenix', 'AZ']
# ['Chadderton manchester']
# ['Bury', 'Greater Manchester']
# ['United Kingdom']
# ['Earth-1218']
# ['MA']
# ['Swansea', 'Wales']
# ['South of London']
# ['Wales', 'United Kingdom']
# ['England', 'United Kingdom']
# ['london']
# ['London Midazolam Deaths ']
# ['Edinburgh', 'The United Kingdom']
# ['Peruvia']
# ['Devizes', 'England']
# ['London', 'England']
# ['Not under a desk']
# [':television: 6:30 p.m. ET']
# ['Manchester', 'England']
# ['Cyprus']
# ['International']
# ['England', 'United Kingdom']
# ['Terf Island']
# ['Wiltshire', 'UK']
# ['Chicago', 'IL']
# ['Leeds/Sheffield']
# ['Huddersfield', 'UK']
# ['Yorkshire']
# ['StocksLand :euro_banknote::dollar_banknote::pound_banknote:']
# ['Scotland ']
# ['Poole', 'England']
# ['Harwich and Manningtree', 'Essex']
# ['Swindon', 'UK']
# ['Venezuela']
# ['UK']
# ['Raipur', 'India']
# ['Southampton', 'England']
# ['Worcester UK']
# ['Cill Mheàrnaig']
# ['Manchester', 'England']
# ['Herefordshire']
# ['Epsom', 'South East']
# ['Brighton']
# ['South East', 'England']
# ['Andalusia', 'Spain']
# ['Cardiff']
# ['Scotland']
# ['England', 'United Kingdom']
# ['east london :United_Kingdom: ']
# ['London/Felpham']
# ['North East', 'England']
# ['UK']
# ['Space Sector 2814']
# ['England', 'United Kingdom']
# ['England']
# ['London']
# ['The Hills', 'Far From People']
# ['#OneClubSince1888']
# ['South East', 'England']
# [':round_pushpin:Essex :woman_technologist_medium-dark_skin_tone::hotel:    ']
# ['Classified']
# ['Chesterfield', 'England']
# ['England']
# ['Pandæmonium']
# ['Earth']
# ['Salford', 'United Kingdom']
# ['NW England']
# ['London', 'England ']
# ['Liverpool']
# ['London']
# ['London', 'England']
# ['Scotland uk ']
# ['In the Fridge ']
# ['𝐿𝑜𝓃𝒹𝑜𝓃 :United_Kingdom:']
# ['Savannah', 'GA']
# ['United Kingdom']
# ['Birmingham', 'England']
# ['California', 'USA', 'Earth']
# ['Glasgow', 'Scotland']
# ['st tropez aka moodiesburn ']
# ['Cardiff', 'Wales']
# ['London', 'via Waterford Ireland']
# ['Everywhere ']
# ['New York', 'NY']
# ['Liverpool', 'England']
# ['Gym or donating platelets ']
# ['London', 'England']
# ['here and there']
# ['England', 'United Kingdom:United_Kingdom:']
# ['Manchester', 'UK']
# ['Srinagar Kashmir']
# ['UK', 'Christendom']
# ['Tamil Nadu', 'India']
# ['bolton']
# ['United States :United_States: /Phila :eagle::eagle:']
# ['Dublin (IE) // Portsmouth (UK)']
# ['Uk']
# ['London', 'England']
# ['Uig', 'Scotland']
# ['London', 'England']
# ['NotVeryUnitedKingdom']
# ['London', 'Glasgow', 'Sodermalm.']
# ['Wrockwardine Wood']
# ['Nepal']
# ['Orlando', 'FL']
# ['Halifax', 'England']
# ['London', 'England']
# ['Tewkesbury', 'England']
# ['Erehwon']
# ['London ma preferisco Parigi :red_heart:️']
# ['Somerset']
# ['Southeast Cornwall :blue_heart:']
# ['London']
# ['London', 'England']
# ['Louisiana', 'USA']
# ['Terf Island']
# ['Florida', 'USA']
# ['Krypton']
# [':Scotland: ']
# ['Glasgow', 'Scotland']
# ['Middle England']
# ['Worcester', 'England']
# ['London', 'England']
# ['Newbury']
# ['London']
# ['The Arsehole of Nowhere']
# ['U.S . Nationwide Global ']
# ['London']
# ['Somewhere on the water']
# ['London', 'England']
# ['London', 'England']
# [' SW Virginia', 'USA']
# ['England', 'United Kingdom']
# ['England', 'United Kingdom']
# ['cornwall']
# [' Somewhere in America']
# ['Fort White', 'FL']
# ['Roanoke', 'VA']
# ['UK']
# ['United Kingdom']
# ['Wales', 'United Kingdom']
# ['Twitter']
# ['Harrogate', 'England']
# ['England', 'United Kingdom']
# ['B91 / Warwickshire ']
# ['City of Brighton & Hove']
# ['LDN']
# ['United Kingdom']
# ['A tiny castle of broken dreams']
# ['London', 'not a nice bit ...']
# ['Birmingham', 'AL']
# ['Midlands/London']
# ['South West', 'England']
# ['England', 'United Kingdom']
# ['Watford', 'England']
# ['Uk']
# ['Hackney', 'London']
# ['England Is England No More']
# [':Scotland:bonnie Scotland :Scotland: ']
# ['London', 'England']
# ['#OrangeTheWorld']
# ['Springfield Missouri']
# ['East Anglia', 'England']
# ['London', 'England']
# ['Cary NC ~antiquitybc@gmail.com']
# ['Owen Sound', 'Ontario']
# ['LDN']
# ['Dorset']
# ['Ottawa.Ont']
# ['Ontario', 'Canada']
# ['Enniscorthy Ireland ']
# ['Johannesburg :South_Africa:']
# ['United Kingdom']
# ['Scottish Borders']
# ['Kingston', 'Jamaica']
# ['UK']
# ['United Kingdom']
# ['England', 'United Kingdom']
# ['Seaford', 'East Sussex', 'England']
# ['Kingston', 'Jamaica :Jamaica:']
# ['North West', 'England']
# ['LONDON']
# ['Aylesbury']
# ['West Midlands', 'England']
# ['Wales', 'United Kingdom']
# ['New Orleans', 'LA']
# ['East Midlands']
# ['Wangland']
# ['Worldwide']
# ['Canada']
# ['Blue Dot', 'Red State of MO']
# ['This Sceptered Isle :United_Kingdom:']
# ['Far side of the moon..']
# ['Uk']
# ['Plumpton', 'East Sussex ']
# ['London']
# ['Sussex By The Sea !']
# ['USA']
# ['Leeds', 'UK']
# ['United Kingdom']
# ['Glasgow', 'Scotland']
# ['London', 'England']
# ['Derby', 'England']
# ['Fashion Nation']
# ['india']
# ['Kerry', 'Ireland']
# ['Lower E']
# ['chesterfield']
# ['Lancing West Sussex England']
# ['Cincinnati', 'OH']
# ['Mars and south Hampshire', 'UK.']
# ['Somewhere comfortable']
# ['Manchester', 'England']
# ['Highlands of Scotland!']
# ['In a van', 'down by the river.']
# ['West Bromwich', 'England']
# ['Colorado Springs', 'CO']
# ['Midwest']
# ['Dorset', 'England']
# ["The 'Burbs of West London"]
# ['North Carolina']
# ['Norfolk UK']
# ['Portsmouth', 'UK.']
# ['Dublin City', 'Ireland']
# ['Broughton', 'Wales']
# ['England', 'United Kingdom']
# ['United Kingdom']
# ['Eastbourne', 'England']
# ['South East', 'England']
# ['Wednesfield', 'England']
# ['London', 'England']
# ['Scotland']
# ['UK']
# ['Aberystwyth', 'Wales']
# ['Auburn', 'AL']
# ['Inter Ripam et mersham ']
# ['Stockport', 'England']
# ['Northern England ']
# ['From London to Darkest Sussex']
# ['Chesterfield']
# ['Kent']
# ['Basildon', 'East']
# ['Liverpool', 'England']
# ['Scotland', 'United Kingdom']
# ['Rome', 'Lazio']
# ['Highley', 'England']
# ['Lost:SOS_button: Wife:red_heart:️ age29 2 Heaven:rose:']
# ['Lincolnshire', 'UK']
# ['London']
# ['United Kingdom']
# ['South West', 'England']
# ['South East', 'England']
# ['west cork']
# ['The Bay']
# ['Birmingham']
# ['anywhere but here']
# ['Brooklyn', 'NY']
# ['Liverpool']
# ['Lancashire']
# ['Narnia ']
# ['Broadstairs', 'England']
# ['West London']
# ['Solihull', 'West Midlands']
# ['London']
# ['London', 'England']
# ['Wimbledon  #RespectYourPolice']
# ['UK']
# ['#RIPRikMayall:red_heart:']
# ['Brighton']
# ['Isle of Wight']
# ['Oklahoma City', 'OK']
# ['Newport', 'Wales', 'UK']
# ['Northampton Midlands ']
# ['Los Angeles', 'CA']
# ['Norfolk,England']
# ['Kent', 'Sussex', 'Surrey & Bromley']
# ['Wales']
# ['I think Earth I might be wrong']
# ['United Kingdom']
# ['Peckham/Paris/New York']
# ['Scotland', 'United Kingdom']
# ['Los Angeles', 'CA']
# ['Somewhere petting a cat']
# ['United States']
# ['Henderson', 'KY', 'USA']
# ['London', 'England']
# ['Blackpool', 'UK']
# ['Barnacre NW England']
# ['England']
# ['London', 'England']
# ['Brancaster ', 'Norfolk ', 'UK']
# ['Within the concrete moat']
# ['North West', 'England']
# ['Millen', 'GA']
# ['Northumberland']
# ['Preston']
# ['London']
# ['Springfield IL']
# ['Harrogate', 'North Yorkshire.']
# ['Liverpool', 'England']
# ['Billerica MA']
# ['italy ... In mind if not body ']
# ['South West', 'England']
# ['U.K.']
# ['stockport']
# ['photo shoot']
# ['London ']
# ['UK']
# ['Queensland', 'Australia']
# ['UK']
# ['Madworld']
# ['Liverpool', 'England']
# ['cheshire']
# ['australia']
# ['London/Yorks/Lancs/ & Wherever']
# ['Jersey Girl!']
# ['England', 'United Kingdom']
# ['SultanGoddess : SultanPLC']
# ['Corby']
# ['Belfast :United_Kingdom: Almeria :Spain:']
# ['England', 'United Kingdom']
# ['The bowels of hell']
# ['UK', 'second city']
# ['U.S.A']
# ['The Wee Emerald Isle']
# ['Greenville', 'Texas']
# ['Ellesmere Port', 'England']
# ['London']
# ['Nottingham', 'England']
# ['Worcester', 'UK']
# ['Kent,England', 'United Kingdom']
# ['Winchester']
# ['Salisbury', 'Wiltshire']
# ['England', 'United Kingdom']
# ['dating linktr.ee/']
# ['Más allá de la duda razonable']
# ['West Midlands', 'England']
# ['SE Asia']
# ['on Twitter', 'and sometimes not.']
# ['Locations available nationwide']
# ["Where I'm ment 2 be"]
# ['South East', 'England']
# ['somewhere peaceful']
# ['Oxford', 'UK']
# ['Seaham']
# ['Nuneaton', 'England']
# ['England', 'United Kingdom']
# ['Watford']
# ['South London ']
# ['London']
# ['Rochester', 'Kent', 'England']
# ['England', 'United Kingdom']
# ['Out Standing in My Field']
# ['Earth ']
# ['Merlin', 'OR']
# ['Cork']
# ['Southampton', 'UK']
# ['Warrington', 'England']
# ['Thame', 'England']
# ['United Kingdom ']
# ['Canberra', 'Ngunnawal country']
# ['South Essex']
# ['Colchester', 'England']
# ['England', 'United Kingdom']
# ['Boston', 'MA']
# ['London']
# ['Scotland']
# ['Newcastle Upon Tyne', 'England']
# ['Romford', 'London']
# ['Norwich', 'England']
# ['West Yorkshire']
# ['Netherlands']
# ['UK']
# ['A galaxy far', 'far away']
# ['Brighton', 'England']
# ['Brighton UK']
# ['United States of America']
# ['London']
# ['Avondale', 'Louisiana']
# ['The Grim Northwest']
# ['Sheffield', 'England']
# ['NE England']
# ['Bas Laurentien']
# ['The Hermitage ']
# ['Cymru Wales']
# ['United Kingdom']
# ['Earth']
# ['United Kingdom']
# ['London']
# ['St Leonards on Sea', 'E. Sussex.']
# ['Brighton UK']
# ['Worthing', 'England']
# ['C-137']
# ['England A Once Great Country.']
# ['Bolton', 'England']
# ['Walthamstow', 'London UK']
# ['Stockton-on-Tees', 'England']
# ['London', 'England']
# ['Johnstone', 'Scotland']
# ['Scotland']
# ['Bologna', 'Emilia Romagna']
# ['Ireland']
# ['Northampton', 'England']
# ['Lancashire']
# ['Manchester', 'UK']
# ['Menston']
# ['UK']
# ['Scotland', 'United Kingdom']
# ['Glasgow', 'Scotland']
# ['Last Movie Outpost']
# ['Brighton', 'England']
# ['Abroad']
# ['Cambridge', 'England']
# ['Hertfordshire']
# ['Not here']
# ['Ham', 'Richmond']
# ['Toronto', 'Ontario']
# ['Brighton Sussex London UK']
# ['Llamedos']
# ['South Yorkshire', 'England']
# ['London']
# ['northwich']
# ['Staffordshire', 'England']
# ['Henley on Thames']
# ['London']
# ['Eastbourne', 'England']
# ['Sunderland', 'UK']
# ['Leeds']
# ['Howell', 'MI']
# ['Durham']
# ['Cabot Cove', 'Maine.']
# ['Dales']
# ['United Kingdom']
# ['Neath', 'Wales']
# ['Kickapoo Territory ']
# ['East Riding Of Yorkshire']
# ['Principal Street', 'Canada']
# ['Royalwhispers is freelance']
# ['Somerset']
# ['Early 1970s']
# ['Citizen Of The World']
# ['England', 'UK']
# ['England', 'United Kingdom']
# ['London', 'England']
# ['Bournemouth']
# ['London', 'England']
# ['Clare', 'East']
# ['England', 'United Kingdom']
# ['Isle of Lewis,Scotland.']
# ['wiltshire']
# ['South East', 'England']
# ['London', 'England']
# ['Pembrokeshire ']
# ['south west']
# ['Manchester', 'England']
# ['Twitter.com']
# ['South Wales', 'UK']
# [':house_with_garden: Birkdale,Northwest .:house_with_garden:']
# ['Twickenham', 'London']
# ['Cambridgeshire']
# ['On the sofa']
# ['Liverpool', 'NY', '#Manus', '#Nauru', 'Berlin']
# ['North Wales', 'UK']
# ['Manchester']
# ['San Antonio', 'Tx']
# ['Manchester', 'England']
# ['Sunderland UK']
# ['North West', 'England']
# ['A little of everywhere ']
# ['London', 'UK']
# ['United Kingdom']
# ['uk']
# ['West Midlands', 'England']
# ['liverpool']
# ['Japan 日本']
# ['Brighton', 'England']
# ['Yorkshire and The Humber']
# ['South East', 'England']
# ['United Kingdom']
# ['Wimbledon', 'England']
# ['Glasgow', 'Scotland']
# ['London/Worcs', 'England']
# ['Colchester Essex']
# ['West Sussex', 'United Kingdom']
# ['Shoreham-by-Sea', 'England']
# ['London', 'N (formally SE)']
# ['Sussex', 'England ']
# ['Glasgow', 'Scotland UK']
# ["N 51°58' 0'' / W 0°15' 0''"]
# ['Manchester']
# ['Pettyville']
# ['New Delhi', 'India']
# ['Eastbourne']
# ['salford']
# ['Worthing', 'England']
# ['Sheffield', 'UK']
# ['essex']
# ['London']
# ['Hampshire']
# ['London', '']
# ['north ayrshire']
# ['Derbyshire via NZ 2 Lancashire']
# ['Coalville', 'England']
# ['Akure', 'Nigeria']
# ['London']
# ['Hullifornia(Hull)']
# ['Yorkshire', 'England']
# ['Al Hoceima', 'Royaume du Maroc']
# ['Dorchester']
# ['London']
# ['London', 'England']
# ['Northumberland & Durham']
# ['Yorkshire']
# ['the deep south.']
# ['Ireland']
# ['Portsmouth', 'England']
# ['Cornwall. UK. ']
# ['Snake Island']
# ['East London via Jamaica']
# ['Tarragona./Glossop ']
# ['London', 'England']
# ['The European Union']
# ['London', 'UK']
# ['North East', 'England']
# ['UK']
# ['Greenwich', 'London']
# ['United Kingdom']
# ['Wivelsfield Green']
# ['Shepherds Bush', 'now Herts ']
# ['UK (south east)']
# ['Rent Free in Your Head']
# ['South East', 'England']
# ['Glasgow']
# ['England', 'UK and proud']
# ['London']
# ['London']
# ['England']
# ['Brighton']
# ['Liverpool']
# ['West Yorkshire']
# ['Cheshire']
# ['ENGLAND']
# ['East Sussex ']
# ['London']
# ['Staffordshire ']
# ['Leicestershire ']
# ['United Kingdom']
# ['Manchester']
# ['Worthing', 'England']
# ['LDN']
# ['Flondyville']
# ['Glasgow', 'Scotland']
# ['East of England']
# ['Preston', 'England']
# ['aberdeen']
# ['England', 'United Kingdom']
# ['UK']
# ['London', 'England']
# ['United Kingdom']
# ['East Sussex']
# ['West Midlands']
# ['London', 'England']
# ['England', 'United Kingdom']
# ['Scotland', 'United Kingdom']
# ['Brighton']
# ['nr Westonbirt', 'Gloucestershire']
# ['England', 'United Kingdom']
# ['slovenia']
# ['Lancastrian in Grim South !']
# ['Dundee']
# ['somewhere but get lost easily ']
# ['Cambridge', 'England']
# ['Manchester']
# ['Bikini Atoll']
# ['Hythe', 'Southampton', 'England']
# ['London']
# ['London']
# ['Lagos', 'Nigeria']
# ['London']
# ['The Shires']
# ['Winchester UK']
# ['West Sussex']
# ['Suffolk', 'UK']
# ['United Kingdom']
# ['London', 'England']
# ['Düsseldorf', 'Germany']
# ['London', 'England']
# ['Eastbourne', 'England']
# ['Shropshire']
# ['Lawrence country']
# ['الساحل الشرقي ']
# ['London']
# ["They won't tell me!"]
# ['RT etc not an endorsement ']
# ['UK']
# ['Christchurch', 'England']
# ['London', 'England']
# ['Arundel', 'England']
# ['North West', 'England']
# ['London', 'England']
# ['Manchester']
# ['MCR']
# ['Oxford', 'United Kingdom']
# ['West Sussex']
# ['London']
# ['Sussex England']
# ['Tower Hamlets', 'London']
# ['Aveley']
# ['Salford', 'England']
# ['Carlisle', 'Cumbria']
# ['North West Sussex']
# ['Manchester', 'England']
# ['South East', 'England']
# ['Doghouse']
# ['INDIVIDUAL MERIT FIRST & LAST']
# ['London']
# ['California', 'USA']
# ['Little Rock', 'AR']
# ['United States']
# ['Vietnam']
# ['Uk']
# ['West Yorkshire']
# ['Everywhere']
# ['London']
# ['United States']
# ['London', 'England']
# ['Sunderland', 'Plague Island']
# ['London', 'United Kingdom']
# ['Hammersmith', 'London']
# ['PalpableDiscordia']
# ['Northern Ireland', 'Uk']
# ['•all black lives matter•']
# ['Abuja,Nigeria']
# ['London', 'UK']
# ['Lodgemoor', 'Sheffield', 'U.K']
# ['Manny:right_arrow:️Souf Landan']
# ['South East', 'England']
# ['UK']
# ['ewell', 'surrey', 'UK']
# ['Forest Hill', 'England']
# ['Anywhere The TTI Tries To Hide']
